# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

data = pd.read_csv("data.csv", parse_dates=["date"], index_col="date")
x = pd.DataFrame(data)
x.head(10)
# Out:
#               signal  spy_close_price
# date
# 2012-01-03  3.107767          127.495
# 2012-01-04  3.107282          127.700
# 2012-01-05  3.099757          128.040
# 2012-01-06  3.134223          127.710
# 2012-01-09  3.135922          128.020
# 2012-01-10  3.143447          129.130
# 2012-01-11  3.127184          129.200
# 2012-01-12  3.139320          129.510
# 2012-01-13  3.174029          128.840
# 2012-01-17  3.190777          129.340

# %% [markdown]
# ## CLEAN UP THE DATA

# %%
#claim: there's a correlation btw signal and close_price

#first step is to clean the data
plt.scatter(x['signal'], x['spy_close_price'])
plt.show()

# %%
linear_data = x
linear_data = linear_data[linear_data.loc[:,'spy_close_price'] < 300]
linear_data = linear_data[linear_data.loc[:,'signal'] < 100]
linear_data = linear_data[linear_data.loc[:,'signal'] > 2]

# %%
plt.scatter(linear_data['signal'], linear_data['spy_close_price'])
plt.show()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Split the data into training/testing sets
X_train = linear_data['signal'][:-20]
X_test = linear_data['signal'][-20:]

# Split the targets into training/testing sets
y_train = linear_data['spy_close_price'][:-20]
y_test = linear_data['spy_close_price'][-20:]

# Create linear regression object
regr = linear_model.LinearRegression()
X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)


# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared = : %.2f' % r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(linear_data['signal'], linear_data['spy_close_price'])
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='red', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [40.82405753]
# Mean squared error: 4.54
# R-squared = : 0.56

# %%
df = x
df = df[df.loc[:,'spy_close_price'] < 300]
df = df[df.loc[:,'spy_close_price'] > 0]

# %%
plt.plot(x.index.tolist(), x['spy_close_price'], '.')
plt.show()

plt.plot(df.index.tolist(), df['spy_close_price'], '.')
plt.show()

# %%
ts = df.drop(columns=['signal'])
ts.head()
# Out:
#             spy_close_price
# date
# 2012-01-03          127.495
# 2012-01-04          127.700
# 2012-01-05          128.040
# 2012-01-06          127.710
# 2012-01-09          128.020

# %%
plt.plot(ts, '.')
plt.show()

# %% [markdown]
# ## SOME COMPUTATION

# %%
from statsmodels.tsa.stattools import adfuller
from pandas.core import datetools
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
# Out:
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
ts_log = np.log(ts)
plt.plot(ts_log)
plt.show()

ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)
plt.show()

# %%
test_stationarity(ts_log_diff)
# Out:
# /anaconda/envs/py3k/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).mean()
#
# /anaconda/envs/py3k/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).std()
#   import sys
# Results of Dickey-Fuller Test:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-17245d6a3578> in <module>()
# ----> 1 test_stationarity(ts_log_diff)
#
# <ipython-input-11-be6b2b07e2e4> in test_stationarity(timeseries)
#      17     #Perform Dickey-Fuller test:
#      18     print ('Results of Dickey-Fuller Test:')
# ---> 19     dftest = adfuller(timeseries, autolag='AIC')
#      20     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      21     for key,value in dftest[4].items():
#
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     218
#     219     xdiff = np.diff(x)
# --> 220     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
#     221     nobs = xdall.shape[0]  # pylint: disable=E1103
#     222
#
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py in lagmat(x, maxlag, trim, original, use_pandas)
#     373     if xa.ndim == 1:
#     374         xa = xa[:, None]
# --> 375     nobs, nvar = xa.shape
#     376     if original in ['ex', 'sep']:
#     377         dropidx = nvar
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ## FORCASTING TIME SERIES

# %%
from statsmodels.tsa.stattools import acf, pacf

ts_log_diff.dropna(inplace=True)

lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')

# %%
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.show()

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()
plt.show()

# %%
ts_log_diff.head()
# Out:
#             spy_close_price
# date
# 2012-01-04         0.001607
# 2012-01-05         0.002659
# 2012-01-06        -0.002581
# 2012-01-09         0.002424
# 2012-01-10         0.008633

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(ts_log, order=(2, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.show()
# Out:
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
model = ARIMA(ts_log, order=(0, 1, 2))  
results_MA = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.show()
# Out:
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
model = ARIMA(ts_log, order=(2, 1, 2))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(ts_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.show()
# Out:
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /anaconda/envs/py3k/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# date
# 2012-01-04    0.000680
# 2012-01-05    0.000655
# 2012-01-06    0.000617
# 2012-01-09    0.000726
# 2012-01-10    0.000605
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print (predictions_ARIMA_diff_cumsum.head())
# Out:
# date
# 2012-01-04    0.000680
# 2012-01-05    0.001335
# 2012-01-06    0.001953
# 2012-01-09    0.002678
# 2012-01-10    0.003283
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(ts_log.iloc[0][0], index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# date
# 2012-01-03    4.848077
# 2012-01-04    4.848757
# 2012-01-05    4.849412
# 2012-01-06    4.850030
# 2012-01-09    4.850755
# dtype: float64

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(predictions_ARIMA)
plt.plot(ts)
plt.show()

# %%
import tensorflow as tf
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
tf.set_random_seed(RANDOM_SEED)


def init_weights(shape):
    """ Weight initialization """
    weights = tf.random_normal(shape, stddev=0.1)
    return tf.Variable(weights)

def forwardprop(X, w_1, w_2):
    """
    Forward-propagation.
    IMPORTANT: yhat is not softmax since TensorFlow's softmax_cross_entropy_with_logits() does that internally.
    """
    h    = tf.nn.sigmoid(tf.matmul(X, w_1))  # The \sigma function
    yhat = tf.matmul(h, w_2)  # The \varphi function
    return yhat

def get_stock_data():
    """ Read the stock data set and split them into training and test sets """
    df = pd.read_csv("data.csv")
    print(df.head())
    data = df['date']
    target = df['spy_close_price']
    print(data.head())
    print(target.head())
    data = data.reshape(1,667)
    target = target.reshape(1,667)
    # Prepend the column of 1s for bias
    N,M = data.shape
    all_X = np.ones((N, M + 1))
    all_X[:, 1:] = data
    # Convert into one-hot vectors
    num_labels = len(np.unique(target))
    all_Y = np.eye(num_labels)[target]  # One liner trick!
    return train_test_split(all_X, all_Y, test_size=0.33, random_state=RANDOM_SEED)

def main():
    train_X, test_X, train_y, test_y = get_stock_data()
    # Layer's sizes
    x_size = train_X.shape[1]   # Number of input nodes: 4 features and 1 bias
    h_size = 256                # Number of hidden nodes
    y_size = train_y.shape[1]   # Number of outcomes (3 iris flowers)

    # Symbols
    X = tf.placeholder("float", shape=[None, x_size])
    y = tf.placeholder("float", shape=[None, y_size])

    # Weight initializations
    w_1 = init_weights((x_size, h_size))
    w_2 = init_weights((h_size, y_size))

    # Forward propagation
    yhat    = forwardprop(X, w_1, w_2)
    predict = tf.argmax(yhat, axis=1)

    # Backward propagation
    cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=yhat))
    updates = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

    # Run SGD
    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)

    for epoch in range(100):
        # Train with each example
        for i in range(len(train_X)):
            sess.run(updates, feed_dict={X: train_X[i: i + 1], y: train_y[i: i + 1]})

        train_accuracy = np.mean(np.argmax(train_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: train_X, y: train_y}))
        test_accuracy  = np.mean(np.argmax(test_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: test_X, y: test_y}))

        print("Epoch = %d, train accuracy = %.2f%%, test accuracy = %.2f%%"
              % (epoch + 1, 100. * train_accuracy, 100. * test_accuracy))

    sess.close()

if __name__ == '__main__':
    main()
# Out:
#        date    signal  spy_close_price
# 0  20120103  3.107767          127.495
# 1  20120104  3.107282          127.700
# 2  20120105  3.099757          128.040
# 3  20120106  3.134223          127.710
# 4  20120109  3.135922          128.020
# 0    20120103
# 1    20120104
# 2    20120105
# 3    20120106
# 4    20120109
# Name: date, dtype: int64
# 0    127.495
# 1    127.700
# 2    128.040
# 3    127.710
# 4    128.020
# Name: spy_close_price, dtype: float64
# Epoch = 1, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 2, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 3, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 4, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 5, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 6, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 7, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 8, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 9, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 10, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 11, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 12, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 13, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 14, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 15, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 16, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 17, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 18, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 19, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 20, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 21, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 22, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 23, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 24, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 25, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 26, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 27, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 28, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 29, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 30, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 31, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 32, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 33, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 34, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 35, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 36, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 37, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 38, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 39, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 40, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 41, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 42, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 43, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 44, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 45, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 46, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 47, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 48, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 49, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 50, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 51, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 52, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 53, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 54, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 55, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 56, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 57, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 58, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 59, train accuracy = nan%, test accuracy = 0.00%
# /anaconda/envs/py3k/lib/python3.6/site-packages/ipykernel_launcher.py:32: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# /anaconda/envs/py3k/lib/python3.6/site-packages/ipykernel_launcher.py:33: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# /anaconda/envs/py3k/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda/envs/py3k/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch = 60, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 61, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 62, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 63, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 64, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 65, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 66, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 67, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 68, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 69, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 70, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 71, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 72, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 73, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 74, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 75, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 76, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 77, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 78, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 79, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 80, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 81, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 82, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 83, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 84, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 85, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 86, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 87, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 88, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 89, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 90, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 91, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 92, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 93, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 94, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 95, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 96, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 97, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 98, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 99, train accuracy = nan%, test accuracy = 0.00%
# Epoch = 100, train accuracy = nan%, test accuracy = 0.00%
